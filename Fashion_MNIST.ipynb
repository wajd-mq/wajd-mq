# %% [markdown]
# <a href="https://colab.research.google.com/github/wajd-mq/wajd-mq/blob/main/Fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================
# Fashion-MNIST Multi-Class Classification
# Deep Neural Network (ANN)
# ======================================


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np


# ======================================
# 1. Load Fashion MNIST Dataset
# ======================================

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()


print("Training Data:", x_train.shape)
print("Testing Data:", x_test.shape)



# ======================================
# 2. Class Names
# ======================================

class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]



# ======================================
# 3. Normalization
# ======================================

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0



# ======================================
# 4. Build ANN Model
# ======================================

model = Sequential([


    Flatten(input_shape=(28,28)),


    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),


    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),


    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),


    Dense(64, activation='relu'),


    Dense(10, activation='softmax')

])



# ======================================
# 5. Compile
# ======================================

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)



model.summary()



# ======================================
# 6. Callbacks
# ======================================

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True
)


reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3
)



# ======================================
# 7. Training
# ======================================

history = model.fit(

    x_train,
    y_train,

    epochs=50,
    batch_size=64,

    validation_split=0.2,

    callbacks=[
        early_stop,
        reduce_lr
    ]

)



# ======================================
# 8. Evaluation
# ======================================

loss, accuracy = model.evaluate(
    x_test,
    y_test
)


print("\nTest Accuracy:", accuracy)
print("Test Loss:", loss)



# ======================================
# 9. Accuracy Plot
# ======================================

plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'], label="Training")
plt.plot(history.history['val_accuracy'], label="Validation")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy")

plt.legend()
plt.grid()
plt.show()



# ======================================
# 10. Prediction Example
# ======================================

index = 15


plt.imshow(
    x_test[index],
    cmap='gray'
)

plt.title(
    "Actual: " + class_names[y_test[index]]
)

plt.axis("off")
plt.show()



prediction = model.predict(
    x_test[index].reshape(1,28,28)
)


predicted_class = np.argmax(prediction)


print(
    "Predicted:",
    class_names[predicted_class]
)

print(
    "Actual:",
    class_names[y_test[index]]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Data: (60000, 28, 28)
# Testing Data: (10000, 28, 28)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 578,634 (2.21 MB)
#  Trainable params: 576,842 (2.20 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.7962 - loss: 0.5665 - val_accuracy: 0.8332 - val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8331 - loss: 0.4557 - val_accuracy: 0.8411 - val_loss: 0.4293 - learning_rate: 0.0010
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8441 - loss: 0.4261 - val_accuracy: 0.8457 - val_loss: 0.4015 - learning_rate: 0.0010
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8549 - loss: 0.3975 - val_accuracy: 0.8516 - val_loss: 0.3946 - learning_rate: 0.0010
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8582 - loss: 0.3860 - val_accuracy: 0.8667 - val_loss: 0.3617 - learning_rate: 0.0010
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8617 - loss: 0.3782 - val_accuracy: 0.8671 - val_loss: 0.3631 - learning_rate: 0.0010
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8659 - loss: 0.3645 - val_accuracy: 0.8713 - val_loss: 0.3531 - learning_rate: 0.0010
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8694 - loss: 0.3520 - val_accuracy: 0.8661 - val_loss: 0.3549 - learning_rate: 0.0010
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8694 - loss: 0.3532 - val_accuracy: 0.8692 - val_loss: 0.3522 - learning_rate: 0.0010
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8725 - loss: 0.3443 - val_accuracy: 0.8815 - val_loss: 0.3223 - learning_rate: 0.0010
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8769 - loss: 0.3390 - val_accuracy: 0.8769 - val_loss: 0.3320 - learning_rate: 0.0010
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8782 - loss: 0.3289 - val_accuracy: 0.8730 - val_loss: 0.3462 - learning_rate: 0.0010
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8810 - loss: 0.3253 - val_accuracy: 0.8595 - val_loss: 0.3810 - learning_rate: 0.0010
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.8886 - loss: 0.3018 - val_accuracy: 0.8839 - val_loss: 0.3129 - learning_rate: 5.0000e-04
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8894 - loss: 0.2953 - val_accuracy: 0.8883 - val_loss: 0.3043 - learning_rate: 5.0000e-04
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.8934 - loss: 0.2867 - val_accuracy: 0.8879 - val_loss: 0.3075 - learning_rate: 5.0000e-04
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8964 - loss: 0.2817 - val_accuracy: 0.8837 - val_loss: 0.3152 - learning_rate: 5.0000e-04
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.8964 - loss: 0.2787 - val_accuracy: 0.8950 - val_loss: 0.2953 - learning_rate: 5.0000e-04
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8976 - loss: 0.2759 - val_accuracy: 0.8897 - val_loss: 0.3060 - learning_rate: 5.0000e-04
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8999 - loss: 0.2696 - val_accuracy: 0.8903 - val_loss: 0.3015 - learning_rate: 5.0000e-04
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.8994 - loss: 0.2698 - val_accuracy: 0.8913 - val_loss: 0.3037 - learning_rate: 5.0000e-04
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.9045 - loss: 0.2568 - val_accuracy: 0.8938 - val_loss: 0.2903 - learning_rate: 2.5000e-04
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9066 - loss: 0.2493 - val_accuracy: 0.8978 - val_loss: 0.2846 - learning_rate: 2.5000e-04
# Epoch 24/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9089 - loss: 0.2462 - val_accuracy: 0.8965 - val_loss: 0.2858 - learning_rate: 2.5000e-04
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9075 - loss: 0.2452 - val_accuracy: 0.8923 - val_loss: 0.2934 - learning_rate: 2.5000e-04
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9094 - loss: 0.2427 - val_accuracy: 0.8957 - val_loss: 0.2902 - learning_rate: 2.5000e-04
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9110 - loss: 0.2367 - val_accuracy: 0.8972 - val_loss: 0.2855 - learning_rate: 1.2500e-04
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9116 - loss: 0.2351 - val_accuracy: 0.9000 - val_loss: 0.2838 - learning_rate: 1.2500e-04
# Epoch 29/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9131 - loss: 0.2325 - val_accuracy: 0.8978 - val_loss: 0.2869 - learning_rate: 1.2500e-04
# Epoch 30/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9131 - loss: 0.2305 - val_accuracy: 0.8991 - val_loss: 0.2843 - learning_rate: 1.2500e-04
# Epoch 31/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9133 - loss: 0.2297 - val_accuracy: 0.8983 - val_loss: 0.2837 - learning_rate: 1.2500e-04
# Epoch 32/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9148 - loss: 0.2295 - val_accuracy: 0.8980 - val_loss: 0.2851 - learning_rate: 1.2500e-04
# Epoch 33/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9158 - loss: 0.2243 - val_accuracy: 0.8980 - val_loss: 0.2895 - learning_rate: 1.2500e-04
# Epoch 34/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9165 - loss: 0.2257 - val_accuracy: 0.8999 - val_loss: 0.2853 - learning_rate: 1.2500e-04
# Epoch 35/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9150 - loss: 0.2208 - val_accuracy: 0.8987 - val_loss: 0.2881 - learning_rate: 6.2500e-05
# Epoch 36/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9165 - loss: 0.2214 - val_accuracy: 0.8986 - val_loss: 0.2857 - learning_rate: 6.2500e-05
# Epoch 37/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9166 - loss: 0.2197 - val_accuracy: 0.8988 - val_loss: 0.2860 - learning_rate: 6.2500e-05
# Epoch 38/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9188 - loss: 0.2173 - val_accuracy: 0.8988 - val_loss: 0.2849 - learning_rate: 3.1250e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8912 - loss: 0.3059
#
# Test Accuracy: 0.8912000060081482
# Test Loss: 0.3059065043926239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Predicted: Trouser
# Actual: Trouser

# %%
# ======================================
# Fashion-MNIST Multi-Class Classification
# Improved Deep Neural Network (ANN)
# No CNN
# ======================================


# Import Libraries

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns



# ======================================
# 1. Load Dataset
# ======================================

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()


print("Training Data:", x_train.shape)
print("Testing Data:", x_test.shape)



# ======================================
# 2. Class Names
# ======================================

class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]



# ======================================
# 3. Normalization
# ======================================

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0



# ======================================
# 4. Build Improved ANN Model
# ======================================

model = Sequential([


    Flatten(input_shape=(28,28)),


    # Layer 1
    Dense(
        512,
        activation='elu',
        kernel_regularizer=l2(0.0001)
    ),
    BatchNormalization(),
    Dropout(0.35),



    # Layer 2
    Dense(
        256,
        activation='elu',
        kernel_regularizer=l2(0.0001)
    ),
    BatchNormalization(),
    Dropout(0.3),



    # Layer 3
    Dense(
        128,
        activation='elu',
        kernel_regularizer=l2(0.0001)
    ),
    BatchNormalization(),
    Dropout(0.25),



    # Layer 4
    Dense(
        64,
        activation='elu'
    ),



    # Output Layer
    Dense(
        10,
        activation='softmax'
    )

])



# ======================================
# 5. Compile Model
# ======================================

model.compile(

    optimizer=Adam(
        learning_rate=0.0005
    ),

    loss='sparse_categorical_crossentropy',

    metrics=['accuracy']

)


model.summary()



# ======================================
# 6. Callbacks
# ======================================

early_stop = EarlyStopping(

    monitor='val_loss',

    patience=10,

    restore_best_weights=True

)



reduce_lr = ReduceLROnPlateau(

    monitor='val_loss',

    factor=0.5,

    patience=3,

    min_lr=1e-6

)



# ======================================
# 7. Train Model
# ======================================

history = model.fit(

    x_train,

    y_train,

    epochs=100,

    batch_size=64,

    validation_split=0.2,

    callbacks=[
        early_stop,
        reduce_lr
    ],

    verbose=1

)



# ======================================
# 8. Evaluate Model
# ======================================

test_loss, test_accuracy = model.evaluate(

    x_test,

    y_test,

    verbose=0

)


print("\n==========================")
print("Test Accuracy:", test_accuracy)
print("Test Loss:", test_loss)
print("==========================")



# ======================================
# 9. Accuracy Plot
# ======================================

plt.figure(figsize=(8,5))


plt.plot(
    history.history['accuracy'],
    label='Training Accuracy'
)


plt.plot(
    history.history['val_accuracy'],
    label='Validation Accuracy'
)


plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")

plt.legend()
plt.grid()

plt.show()



# ======================================
# 10. Loss Plot
# ======================================

plt.figure(figsize=(8,5))


plt.plot(
    history.history['loss'],
    label='Training Loss'
)


plt.plot(
    history.history['val_loss'],
    label='Validation Loss'
)


plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Model Loss")

plt.legend()
plt.grid()

plt.show()



# ======================================
# 11. Prediction Example
# ======================================

index = 25


plt.imshow(
    x_test[index],
    cmap='gray'
)

plt.title(
    "Actual: " + class_names[y_test[index]]
)

plt.axis("off")

plt.show()



prediction = model.predict(
    x_test[index].reshape(1,28,28)
)


predicted_class = np.argmax(prediction)



print(
    "Predicted:",
    class_names[predicted_class]
)


print(
    "Actual:",
    class_names[y_test[index]]
)



# ======================================
# 12. Confusion Matrix
# ======================================


y_pred = np.argmax(

    model.predict(x_test),

    axis=1

)



print(
    classification_report(

        y_test,

        y_pred,

        target_names=class_names

    )
)



cm = confusion_matrix(

    y_test,

    y_pred

)



plt.figure(figsize=(10,8))


sns.heatmap(

    cm,

    annot=True,

    fmt='d',

    cmap='Blues',

    xticklabels=class_names,

    yticklabels=class_names

)


plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()
# Out:
# Training Data: (60000, 28, 28)
# Testing Data: (10000, 28, 28)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 578,634 (2.21 MB)
#  Trainable params: 576,842 (2.20 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# Epoch 1/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 32s 22ms/step - accuracy: 0.7940 - loss: 0.6871 - val_accuracy: 0.8434 - val_loss: 0.5412 - learning_rate: 5.0000e-04
# Epoch 2/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8379 - loss: 0.5515 - val_accuracy: 0.8592 - val_loss: 0.4925 - learning_rate: 5.0000e-04
# Epoch 3/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8521 - loss: 0.5106 - val_accuracy: 0.8658 - val_loss: 0.4640 - learning_rate: 5.0000e-04
# Epoch 4/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.8576 - loss: 0.4849 - val_accuracy: 0.8650 - val_loss: 0.4713 - learning_rate: 5.0000e-04
# Epoch 5/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8649 - loss: 0.4683 - val_accuracy: 0.8629 - val_loss: 0.4547 - learning_rate: 5.0000e-04
# Epoch 6/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8679 - loss: 0.4547 - val_accuracy: 0.8727 - val_loss: 0.4456 - learning_rate: 5.0000e-04
# Epoch 7/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.8707 - loss: 0.4427 - val_accuracy: 0.8756 - val_loss: 0.4277 - learning_rate: 5.0000e-04
# Epoch 8/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8749 - loss: 0.4319 - val_accuracy: 0.8794 - val_loss: 0.4224 - learning_rate: 5.0000e-04
# Epoch 9/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8775 - loss: 0.4242 - val_accuracy: 0.8664 - val_loss: 0.4445 - learning_rate: 5.0000e-04
# Epoch 10/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8774 - loss: 0.4206 - val_accuracy: 0.8760 - val_loss: 0.4338 - learning_rate: 5.0000e-04
# Epoch 11/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.8789 - loss: 0.4098 - val_accuracy: 0.8793 - val_loss: 0.4184 - learning_rate: 5.0000e-04
# Epoch 12/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8809 - loss: 0.4030 - val_accuracy: 0.8714 - val_loss: 0.4369 - learning_rate: 5.0000e-04
# Epoch 13/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.8824 - loss: 0.4010 - val_accuracy: 0.8824 - val_loss: 0.4063 - learning_rate: 5.0000e-04
# Epoch 14/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8842 - loss: 0.3944 - val_accuracy: 0.8881 - val_loss: 0.3960 - learning_rate: 5.0000e-04
# Epoch 15/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.8854 - loss: 0.3913 - val_accuracy: 0.8828 - val_loss: 0.4060 - learning_rate: 5.0000e-04
# Epoch 16/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8867 - loss: 0.3879 - val_accuracy: 0.8839 - val_loss: 0.3923 - learning_rate: 5.0000e-04
# Epoch 17/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8874 - loss: 0.3836 - val_accuracy: 0.8825 - val_loss: 0.3987 - learning_rate: 5.0000e-04
# Epoch 18/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.8883 - loss: 0.3788 - val_accuracy: 0.8745 - val_loss: 0.4209 - learning_rate: 5.0000e-04
# Epoch 19/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.8899 - loss: 0.3765 - val_accuracy: 0.8736 - val_loss: 0.4323 - learning_rate: 5.0000e-04
# Epoch 20/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.8984 - loss: 0.3499 - val_accuracy: 0.8875 - val_loss: 0.3824 - learning_rate: 2.5000e-04
# Epoch 21/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.8990 - loss: 0.3440 - val_accuracy: 0.8913 - val_loss: 0.3729 - learning_rate: 2.5000e-04
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.9014 - loss: 0.3395 - val_accuracy: 0.8849 - val_loss: 0.3874 - learning_rate: 2.5000e-04
# Epoch 23/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9027 - loss: 0.3334 - val_accuracy: 0.8903 - val_loss: 0.3700 - learning_rate: 2.5000e-04
# Epoch 24/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9036 - loss: 0.3309 - val_accuracy: 0.8875 - val_loss: 0.3828 - learning_rate: 2.5000e-04
# Epoch 25/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9050 - loss: 0.3259 - val_accuracy: 0.8907 - val_loss: 0.3678 - learning_rate: 2.5000e-04
# Epoch 26/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9038 - loss: 0.3254 - val_accuracy: 0.8909 - val_loss: 0.3724 - learning_rate: 2.5000e-04
# Epoch 27/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9045 - loss: 0.3240 - val_accuracy: 0.8901 - val_loss: 0.3828 - learning_rate: 2.5000e-04
# Epoch 28/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9057 - loss: 0.3227 - val_accuracy: 0.8918 - val_loss: 0.3668 - learning_rate: 2.5000e-04
# Epoch 29/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9069 - loss: 0.3178 - val_accuracy: 0.8968 - val_loss: 0.3598 - learning_rate: 2.5000e-04
# Epoch 30/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9061 - loss: 0.3152 - val_accuracy: 0.8892 - val_loss: 0.3754 - learning_rate: 2.5000e-04
# Epoch 31/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.9063 - loss: 0.3155 - val_accuracy: 0.8903 - val_loss: 0.3795 - learning_rate: 2.5000e-04
# Epoch 32/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.9068 - loss: 0.3151 - val_accuracy: 0.8876 - val_loss: 0.3814 - learning_rate: 2.5000e-04
# Epoch 33/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9120 - loss: 0.2969 - val_accuracy: 0.8996 - val_loss: 0.3503 - learning_rate: 1.2500e-04
# Epoch 34/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9140 - loss: 0.2915 - val_accuracy: 0.8961 - val_loss: 0.3536 - learning_rate: 1.2500e-04
# Epoch 35/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9154 - loss: 0.2876 - val_accuracy: 0.8978 - val_loss: 0.3534 - learning_rate: 1.2500e-04
# Epoch 36/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.9160 - loss: 0.2870 - val_accuracy: 0.9000 - val_loss: 0.3496 - learning_rate: 1.2500e-04
# Epoch 37/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.9140 - loss: 0.2880 - val_accuracy: 0.8972 - val_loss: 0.3513 - learning_rate: 1.2500e-04
# Epoch 38/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9157 - loss: 0.2857 - val_accuracy: 0.8938 - val_loss: 0.3567 - learning_rate: 1.2500e-04
# Epoch 39/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9165 - loss: 0.2840 - val_accuracy: 0.8970 - val_loss: 0.3484 - learning_rate: 1.2500e-04
# Epoch 40/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9168 - loss: 0.2807 - val_accuracy: 0.8964 - val_loss: 0.3521 - learning_rate: 1.2500e-04
# Epoch 41/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9164 - loss: 0.2829 - val_accuracy: 0.8976 - val_loss: 0.3540 - learning_rate: 1.2500e-04
# Epoch 42/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9181 - loss: 0.2774 - val_accuracy: 0.8982 - val_loss: 0.3503 - learning_rate: 1.2500e-04
# Epoch 43/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9210 - loss: 0.2685 - val_accuracy: 0.8994 - val_loss: 0.3459 - learning_rate: 6.2500e-05
# Epoch 44/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.9210 - loss: 0.2680 - val_accuracy: 0.9003 - val_loss: 0.3446 - learning_rate: 6.2500e-05
# Epoch 45/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9219 - loss: 0.2660 - val_accuracy: 0.9011 - val_loss: 0.3399 - learning_rate: 6.2500e-05
# Epoch 46/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9227 - loss: 0.2638 - val_accuracy: 0.9002 - val_loss: 0.3416 - learning_rate: 6.2500e-05
# Epoch 47/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9239 - loss: 0.2616 - val_accuracy: 0.9013 - val_loss: 0.3449 - learning_rate: 6.2500e-05
# Epoch 48/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9228 - loss: 0.2621 - val_accuracy: 0.8992 - val_loss: 0.3481 - learning_rate: 6.2500e-05
# Epoch 49/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9248 - loss: 0.2573 - val_accuracy: 0.9022 - val_loss: 0.3386 - learning_rate: 3.1250e-05
# Epoch 50/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9262 - loss: 0.2549 - val_accuracy: 0.9007 - val_loss: 0.3422 - learning_rate: 3.1250e-05
# Epoch 51/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9267 - loss: 0.2539 - val_accuracy: 0.9012 - val_loss: 0.3423 - learning_rate: 3.1250e-05
# Epoch 52/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9241 - loss: 0.2554 - val_accuracy: 0.9021 - val_loss: 0.3385 - learning_rate: 3.1250e-05
# Epoch 53/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.9246 - loss: 0.2527 - val_accuracy: 0.9032 - val_loss: 0.3386 - learning_rate: 3.1250e-05
# Epoch 54/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.9263 - loss: 0.2496 - val_accuracy: 0.9015 - val_loss: 0.3425 - learning_rate: 3.1250e-05
# Epoch 55/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.9275 - loss: 0.2497 - val_accuracy: 0.9017 - val_loss: 0.3371 - learning_rate: 3.1250e-05
# Epoch 56/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.9261 - loss: 0.2528 - val_accuracy: 0.9018 - val_loss: 0.3400 - learning_rate: 3.1250e-05
# Epoch 57/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9260 - loss: 0.2498 - val_accuracy: 0.9006 - val_loss: 0.3421 - learning_rate: 3.1250e-05
# Epoch 58/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9258 - loss: 0.2505 - val_accuracy: 0.8990 - val_loss: 0.3433 - learning_rate: 3.1250e-05
# Epoch 59/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9272 - loss: 0.2480 - val_accuracy: 0.9027 - val_loss: 0.3394 - learning_rate: 1.5625e-05
# Epoch 60/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9284 - loss: 0.2463 - val_accuracy: 0.9038 - val_loss: 0.3372 - learning_rate: 1.5625e-05
# Epoch 61/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9278 - loss: 0.2467 - val_accuracy: 0.9031 - val_loss: 0.3383 - learning_rate: 1.5625e-05
# Epoch 62/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9295 - loss: 0.2433 - val_accuracy: 0.9027 - val_loss: 0.3377 - learning_rate: 7.8125e-06
# Epoch 63/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9292 - loss: 0.2446 - val_accuracy: 0.9022 - val_loss: 0.3386 - learning_rate: 7.8125e-06
# Epoch 64/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9286 - loss: 0.2445 - val_accuracy: 0.9015 - val_loss: 0.3394 - learning_rate: 7.8125e-06
# Epoch 65/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9309 - loss: 0.2421 - val_accuracy: 0.9014 - val_loss: 0.3396 - learning_rate: 3.9063e-06
#
# ==========================
# Test Accuracy: 0.8977000117301941
# Test Loss: 0.3605138659477234
# ==========================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Predicted: Pullover
# Actual: Coat
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.85      0.85      1000
#      Trouser       0.98      0.98      0.98      1000
#     Pullover       0.82      0.84      0.83      1000
#        Dress       0.90      0.89      0.89      1000
#         Coat       0.83      0.84      0.84      1000
#       Sandal       0.98      0.95      0.97      1000
#        Shirt       0.74      0.71      0.73      1000
#      Sneaker       0.95      0.96      0.95      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle boot       0.95      0.97      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
